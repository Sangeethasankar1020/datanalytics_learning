# %% [markdown]
# #  EDA - Exploratory Data Analysis

# %% [markdown]
# ### what is EDA ?

# %% [markdown]
# EDA is an approach to analyzing data sets to summarize their main characteristics,often with visuals methods.The goal of EDA is to gain nsghts into the data, uncover underlying patterns and check the quality of the data before appllying more methods

# %% [markdown]
# - Data Collection
# - Data Understanding
# - Data Cleaning
# - Data Transformation
# - Data Visualization

# %% [markdown]
# # Data Collection

# %% [markdown]
# Data Collection is often the first step in the data analysis pipeline and involves gathering data from various sources suh as databases,APIs,web scraping ,or files like CSVs ,Excel ,etc

# %% [markdown]
# ### Installing and importing the libraries

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#after install you have to restart kernel

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Array --> contains the elements with same data type
#numpy - numerical python - number(array)
#pandas - data - analysis, clean(series,dataframe)
#numpy , pandas - its integrate with other libaries
#matplotlib - inside another library import - 
#seaborn - single line plot makes

# %%
df=pd.read_csv("C:/Users/DELL 4/Desktop/data analystics/sample files/super_market.csv")

# %%
df
# Out:
#     Invoice ID Branch         City Customer type  Gender Product line  \
# 0            1      A     New York        Member    Male       Fruits
# 1            2      B  Los Angeles    Non-member  Female        Dairy
# 2            3      C      Chicago        Member  Female       Bakery
# 3            4      A     New York    Non-member    Male       Grains
# 4            5      B  Los Angeles        Member  Female         Meat
# ..         ...    ...          ...           ...     ...          ...
# 69          70      A     New York    Non-member    Male       Grains
# 70          71      A     New York        Member  Female         Meat
# 71          72      B  Los Angeles    Non-member    Male       Fruits
# 72          73      C      Chicago        Member  Female        Dairy
# 73          74      A     New York    Non-member    Male       Bakery
#
#     Unit price  Quantity  Tax 5%  Total        Date   Time      Payment  \
# ...

# %%
df.head()
# Out:
#    Invoice ID Branch         City Customer type  Gender Product line  \
# 0           1      A     New York        Member    Male       Fruits
# 1           2      B  Los Angeles    Non-member  Female        Dairy
# 2           3      C      Chicago        Member  Female       Bakery
# 3           4      A     New York    Non-member    Male       Grains
# 4           5      B  Los Angeles        Member  Female         Meat
#
#    Unit price  Quantity  Tax 5%  Total        Date   Time      Payment  cogs  \
# 0         2.0        10    1.00  21.00  2023-01-01  10:00  Credit Card  20.0
# 1         1.5         5    0.38   8.88  2023-01-01  11:00   Debit Card   7.5
# 2         3.0         2    0.30   6.60  2023-01-02  12:00         Cash   6.0
# 3         1.0         8    0.40   8.40  2023-01-02  14:00  Credit Card   8.0
# 4         5.0         3    0.75  15.75  2023-01-03  15:00         Cash  15.0
#
#    gross margin percentage  gross income  Rating
# ...

# %%
df1=pd.read_csv("super_market.csv") #upload from jupiter

# %%
df1
# Out:
#     Invoice ID Branch         City Customer type  Gender Product line  \
# 0            1      A     New York        Member    Male       Fruits
# 1            2      B  Los Angeles    Non-member  Female        Dairy
# 2            3      C      Chicago        Member  Female       Bakery
# 3            4      A     New York    Non-member    Male       Grains
# 4            5      B  Los Angeles        Member  Female         Meat
# ..         ...    ...          ...           ...     ...          ...
# 69          70      A     New York    Non-member    Male       Grains
# 70          71      A     New York        Member  Female         Meat
# 71          72      B  Los Angeles    Non-member    Male       Fruits
# 72          73      C      Chicago        Member  Female        Dairy
# 73          74      A     New York    Non-member    Male       Bakery
#
#     Unit price  Quantity  Tax 5%  Total        Date   Time      Payment  \
# ...

# %% [markdown]
# # Data understanding

# %% [markdown]
# Data understanding is the process of exploring and getting familiar with your dataset.it involves looking at the data's format,structure,and content to identity any issues or inconsistencies that might need to be addressed before you proceed with further analysis.

# %%
#few rows
df1.head()
# Out:
#    Invoice ID Branch         City Customer type  Gender Product line  \
# 0           1      A     New York        Member    Male       Fruits
# 1           2      B  Los Angeles    Non-member  Female        Dairy
# 2           3      C      Chicago        Member  Female       Bakery
# 3           4      A     New York    Non-member    Male       Grains
# 4           5      B  Los Angeles        Member  Female         Meat
#
#    Unit price  Quantity  Tax 5%  Total        Date   Time      Payment  cogs  \
# 0         2.0        10    1.00  21.00  2023-01-01  10:00  Credit Card  20.0
# 1         1.5         5    0.38   8.88  2023-01-01  11:00   Debit Card   7.5
# 2         3.0         2    0.30   6.60  2023-01-02  12:00         Cash   6.0
# 3         1.0         8    0.40   8.40  2023-01-02  14:00  Credit Card   8.0
# 4         5.0         3    0.75  15.75  2023-01-03  15:00         Cash  15.0
#
#    gross margin percentage  gross income  Rating
# ...

# %%
df1.tail()
#we can view 10 
df1.tail(10)
# Out:
#     Invoice ID Branch         City Customer type  Gender Product line  \
# 64          65      B  Los Angeles        Member  Female       Grains
# 65          66      C      Chicago    Non-member    Male         Meat
# 66          67      A     New York        Member  Female       Fruits
# 67          68      B  Los Angeles    Non-member    Male        Dairy
# 68          69      C      Chicago        Member  Female       Bakery
# 69          70      A     New York    Non-member    Male       Grains
# 70          71      A     New York        Member  Female         Meat
# 71          72      B  Los Angeles    Non-member    Male       Fruits
# 72          73      C      Chicago        Member  Female        Dairy
# 73          74      A     New York    Non-member    Male       Bakery
#
#     Unit price  Quantity  Tax 5%  Total        Date   Time      Payment  \
# 64        1.50         8    0.60  12.60  2023-02-02  15:00         Cash
# ...

# %%
#display summary statistics
df1.describe()
# Out:
#        Invoice ID  Unit price   Quantity     Tax 5%      Total       cogs  \
# count   74.000000   74.000000  74.000000  74.000000  74.000000  73.000000
# mean    37.500000    2.802703   5.418919   0.637432  13.738108  12.726712
# std     21.505813    1.564545   2.415740   0.247232   5.310375   4.986392
# min      1.000000    1.000000   2.000000   0.270000   5.670000   5.400000
# 25%     19.250000    1.750000   3.250000   0.410000   9.082500   8.000000
# 50%     37.500000    2.300000   5.000000   0.630000  13.815000  12.600000
# 75%     55.750000    3.400000   7.750000   0.770000  17.000000  15.400000
# max     74.000000    6.500000  10.000000   1.200000  25.200000  24.000000
#
#        gross margin percentage  gross income     Rating
# count                73.000000     73.000000  73.000000
# mean                  5.753425      0.983151  82.945205
# std                   1.801086      0.498182   7.691789
# min                   5.000000      0.270000  60.000000
# ...

# %%
#some information missing in describe compared to original data, 
#why its not displayed its under categorical order , its only hsow numberical columns

# %%
#50 % - inter quadrialteral range

# %%
#minumum columns - so its diplay , for maximum columns to avoid scroll

# %%
df1.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
#categorical - so its showing - object

# %%
#we can view what datatype catgorical columns has by dtypes

# %%
df1.dtypes
# Out:
# Invoice ID                   int64
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
#we can change dtypes also for our convinient

# %%
#whole information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               74 non-null     int64
#  1   Branch                   74 non-null     object
#  2   City                     74 non-null     object
#  3   Customer type            74 non-null     object
#  4   Gender                   74 non-null     object
#  5   Product line             74 non-null     object
#  6   Unit price               74 non-null     float64
#  7   Quantity                 74 non-null     int64
#  8   Tax 5%                   74 non-null     float64
#  9   Total                    74 non-null     float64
#  10  Date                     74 non-null     object
#  11  Time                     73 non-null     object
#  12  Payment                  73 non-null     object
#  13  cogs                     73 non-null     float64
# ...

# %%
#we can know null values of the datasets

# %%
#no of unique values

# %%
df.nunique()
# Out:
# Invoice ID                 74
# Branch                      3
# City                        3
# Customer type               2
# Gender                      2
# Product line                6
# Unit price                 21
# Quantity                    9
# Tax 5%                     27
# Total                      32
# Date                       38
# Time                       10
# Payment                     3
# cogs                       29
# gross margin percentage     2
# gross income               26
# Rating                     11
# dtype: int64

# %%
#duplicate values

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 69    False
# 70    False
# 71    False
# 72    False
# 73    False
# Length: 74, dtype: bool

# %%
#we can view by sum also

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#to find null values

# %%
df.isnull()
# Out:
#     Invoice ID  Branch   City  Customer type  Gender  Product line  \
# 0        False   False  False          False   False         False
# 1        False   False  False          False   False         False
# 2        False   False  False          False   False         False
# 3        False   False  False          False   False         False
# 4        False   False  False          False   False         False
# ..         ...     ...    ...            ...     ...           ...
# 69       False   False  False          False   False         False
# 70       False   False  False          False   False         False
# 71       False   False  False          False   False         False
# 72       False   False  False          False   False         False
# 73       False   False  False          False   False         False
#
#     Unit price  Quantity  Tax 5%  Total   Date   Time  Payment   cogs  \
# 0        False     False   False  False  False  False    False  False
# ...

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       1
# Payment                    1
# cogs                       1
# gross margin percentage    1
# gross income               1
# Rating                     1
# dtype: int64

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Data Cleaning is the process of preparing your data for analysis by fixing or removing errors and inconsistence

# %%
#fill null value

# %%
#specific column fetch

# %%
df1['Payment']
# Out:
# 0     Credit Card
# 1      Debit Card
# 2            Cash
# 3     Credit Card
# 4            Cash
#          ...
# 69     Debit Card
# 70           Cash
# 71    Credit Card
# 72     Debit Card
# 73            NaN
# Name: Payment, Length: 74, dtype: object

# %%
#its like a series

# %%
df1['Payment'].fillna('ABBC')
# Out:
# 0     Credit Card
# 1      Debit Card
# 2            Cash
# 3     Credit Card
# 4            Cash
#          ...
# 69     Debit Card
# 70           Cash
# 71    Credit Card
# 72     Debit Card
# 73           ABBC
# Name: Payment, Length: 74, dtype: object

# %%
#to replace in original dataframe - inplace

# %%
df1['Payment'].fillna('ABBC',inplace=True)

# %%
df1
# Out:
#     Invoice ID Branch         City Customer type  Gender Product line  \
# 0            1      A     New York        Member    Male       Fruits
# 1            2      B  Los Angeles    Non-member  Female        Dairy
# 2            3      C      Chicago        Member  Female       Bakery
# 3            4      A     New York    Non-member    Male       Grains
# 4            5      B  Los Angeles        Member  Female         Meat
# ..         ...    ...          ...           ...     ...          ...
# 69          70      A     New York    Non-member    Male       Grains
# 70          71      A     New York        Member  Female         Meat
# 71          72      B  Los Angeles    Non-member    Male       Fruits
# 72          73      C      Chicago        Member  Female        Dairy
# 73          74      A     New York    Non-member    Male       Bakery
#
#     Unit price  Quantity  Tax 5%  Total        Date   Time      Payment  \
# ...

# %%
#to drop columns

# %%
df.drop(['cogs'],axis=1,inplace=True) # columns wise zxis =1

# %%
df
# Out:
#     Invoice ID Branch         City Customer type  Gender Product line  \
# 0            1      A     New York        Member    Male       Fruits
# 1            2      B  Los Angeles    Non-member  Female        Dairy
# 2            3      C      Chicago        Member  Female       Bakery
# 3            4      A     New York    Non-member    Male       Grains
# 4            5      B  Los Angeles        Member  Female         Meat
# ..         ...    ...          ...           ...     ...          ...
# 69          70      A     New York    Non-member    Male       Grains
# 70          71      A     New York        Member  Female         Meat
# 71          72      B  Los Angeles    Non-member    Male       Fruits
# 72          73      C      Chicago        Member  Female        Dairy
# 73          74      A     New York    Non-member    Male       Bakery
#
#     Unit price  Quantity  Tax 5%  Total        Date   Time      Payment  \
# ...

# %%
#we can use forward , backward fill , mean value - effective

# %%
df['gross margin percentage'].mean()
# Out:
# 5.7534246575342465

# %%
df['gross margin percentage'].fillna(df['gross margin percentage'].mean(),inplace=True)
# Out:
# C:\Users\DELL 4\AppData\Local\Temp\ipykernel_14984\3155892712.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['gross margin percentage'].fillna(df['gross margin percentage'].mean(),inplace=True)

# %%
df
# Out:
#     Invoice ID Branch         City Customer type  Gender Product line  \
# 0            1      A     New York        Member    Male       Fruits
# 1            2      B  Los Angeles    Non-member  Female        Dairy
# 2            3      C      Chicago        Member  Female       Bakery
# 3            4      A     New York    Non-member    Male       Grains
# 4            5      B  Los Angeles        Member  Female         Meat
# ..         ...    ...          ...           ...     ...          ...
# 69          70      A     New York    Non-member    Male       Grains
# 70          71      A     New York        Member  Female         Meat
# 71          72      B  Los Angeles    Non-member    Male       Fruits
# 72          73      C      Chicago        Member  Female        Dairy
# 73          74      A     New York    Non-member    Male       Bakery
#
#     Unit price  Quantity  Tax 5%  Total        Date   Time      Payment  \
# ...

# %%
#fix errors by replace

# %%
df['Payment']=df['Payment'].replace('Cash','cash')
df
# Out:
#     Invoice ID Branch         City Customer type  Gender Product line  \
# 0            1      A     New York        Member    Male       Fruits
# 1            2      B  Los Angeles    Non-member  Female        Dairy
# 2            3      C      Chicago        Member  Female       Bakery
# 3            4      A     New York    Non-member    Male       Grains
# 4            5      B  Los Angeles        Member  Female         Meat
# ..         ...    ...          ...           ...     ...          ...
# 69          70      A     New York    Non-member    Male       Grains
# 70          71      A     New York        Member  Female         Meat
# 71          72      B  Los Angeles    Non-member    Male       Fruits
# 72          73      C      Chicago        Member  Female        Dairy
# 73          74      A     New York    Non-member    Male       Bakery
#
#     Unit price  Quantity  Tax 5%  Total        Date   Time      Payment  \
# ...

# %% [markdown]
# # Data Transformation

# %% [markdown]
# Data Transformation in python involves converting data from one format or structure to another to make it suitable for analysis or modelling.

# %%
#astype

# %%
df['Rating'].fillna(df['Rating'].mean(),inplace=True)
df['Rating']=df['Rating'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 df['Rating']=df['Rating'].astype('int')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
# ...
