# %% [markdown]
# # Data Loading

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\DELL 4\Downloads\OA_SMS.admissions.csv")

# %%
data
# Out:
#                                       _id        date  active  archive  \
# 0    638522dd-fa2d-4c67-8aae-544851c80d38  05-06-2023    True    False
# 1    d1a7329a-e789-42e9-b073-94393a4ca018  05-06-2023    True    False
# 2    1d49d255-de83-473f-9647-97e1b73e089f  05-06-2023    True    False
# 3    85f98352-115d-4681-867a-051885afbea7  05-06-2023    True    False
# 4    bb0f9261-292e-4658-b327-b03841e80c9c  05-06-2023    True    False
# ..                                    ...         ...     ...      ...
# 522  95464410-e036-4d56-bd8d-98cbf06022a7  09-11-2024    True    False
# 523  73de38d3-b32f-4113-9cd2-e8fc19f88104  14-11-2024    True    False
# 524  983c5737-1beb-4efa-8e35-9bc78ab92541  14-11-2024    True    False
# 525  da39a398-eba1-4ce9-be4c-d370630d2f9e  14-11-2024    True    False
# 526  806481b8-888d-429b-92f9-7509c8ebf4aa  19-11-2024    True    False
#
#     coursestatus certificateCollectedStatus              name         dob  \
# ...

# %%
data=pd.read_excel(r"C:\Users\DELL 4\Downloads\OA_SMS.admissions.xlsx")

# %%
data
# Out:
#                                       _id        date  active  archive  \
# 0    638522dd-fa2d-4c67-8aae-544851c80d38  05-06-2023    True    False
# 1    d1a7329a-e789-42e9-b073-94393a4ca018  05-06-2023    True    False
# 2    1d49d255-de83-473f-9647-97e1b73e089f  05-06-2023    True    False
# 3    85f98352-115d-4681-867a-051885afbea7  05-06-2023    True    False
# 4    bb0f9261-292e-4658-b327-b03841e80c9c  05-06-2023    True    False
# ..                                    ...         ...     ...      ...
# 522  95464410-e036-4d56-bd8d-98cbf06022a7  09-11-2024    True    False
# 523  73de38d3-b32f-4113-9cd2-e8fc19f88104  14-11-2024    True    False
# 524  983c5737-1beb-4efa-8e35-9bc78ab92541  14-11-2024    True    False
# 525  da39a398-eba1-4ce9-be4c-d370630d2f9e  14-11-2024    True    False
# 526  806481b8-888d-429b-92f9-7509c8ebf4aa  19-11-2024    True    False
#
#     coursestatus certificateCollectedStatus              name         dob  \
# ...

# %%
import pandas as pd

data = pd.read_csv("sales_data_sample.csv", encoding='latin1')

# %%
data
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
data=pd.read_csv("OA_SMS.admissions.csv")

# %%
data
# Out:
#                                       _id        date  active  archive  \
# 0    638522dd-fa2d-4c67-8aae-544851c80d38  05-06-2023    True    False
# 1    d1a7329a-e789-42e9-b073-94393a4ca018  05-06-2023    True    False
# 2    1d49d255-de83-473f-9647-97e1b73e089f  05-06-2023    True    False
# 3    85f98352-115d-4681-867a-051885afbea7  05-06-2023    True    False
# 4    bb0f9261-292e-4658-b327-b03841e80c9c  05-06-2023    True    False
# ..                                    ...         ...     ...      ...
# 522  95464410-e036-4d56-bd8d-98cbf06022a7  09-11-2024    True    False
# 523  73de38d3-b32f-4113-9cd2-e8fc19f88104  14-11-2024    True    False
# 524  983c5737-1beb-4efa-8e35-9bc78ab92541  14-11-2024    True    False
# 525  da39a398-eba1-4ce9-be4c-d370630d2f9e  14-11-2024    True    False
# 526  806481b8-888d-429b-92f9-7509c8ebf4aa  19-11-2024    True    False
#
#     coursestatus certificateCollectedStatus              name         dob  \
# ...

# %%
data.head()
# Out:
#                                     _id        date  active  archive  \
# 0  638522dd-fa2d-4c67-8aae-544851c80d38  05-06-2023    True    False
# 1  d1a7329a-e789-42e9-b073-94393a4ca018  05-06-2023    True    False
# 2  1d49d255-de83-473f-9647-97e1b73e089f  05-06-2023    True    False
# 3  85f98352-115d-4681-867a-051885afbea7  05-06-2023    True    False
# 4  bb0f9261-292e-4658-b327-b03841e80c9c  05-06-2023    True    False
#
#   coursestatus certificateCollectedStatus              name         dob  \
# 0    completed                        Yes       JAYAKUMAR J  2000-03-19
# 1    completed                        Yes           SATHISH  2000-02-07
# 2    completed                        Yes  SUNDARAMOORTHY L  1999-11-14
# 3    completed                        Yes          SHYAMA M  2000-11-24
# 4    completed                        Yes           Surya R  2000-03-03
#
#    mobileNumber                                            address  ...  \
# ...

# %%
data.head(2)
# Out:
#                                     _id        date  active  archive  \
# 0  638522dd-fa2d-4c67-8aae-544851c80d38  05-06-2023    True    False
# 1  d1a7329a-e789-42e9-b073-94393a4ca018  05-06-2023    True    False
#
#   coursestatus certificateCollectedStatus         name         dob  \
# 0    completed                        Yes  JAYAKUMAR J  2000-03-19
# 1    completed                        Yes      SATHISH  2000-02-07
#
#    mobileNumber                                            address  ...  \
# 0    8524931434  Thirumalai Nagar, Sanniyasikuppam, Thirubuvana...  ...
# 1    7010996304  No.11, by, priyadarshini nagar orleanpet puduc...  ...
#
#                                                photo    pattern parentNumber  \
# 0  https://firebasestorage.googleapis.com/v0/b/oa...  Full-time   9787958489
# 1  https://firebasestorage.googleapis.com/v0/b/oa...  Full-time   9952114485
#
#   __v studentId       regNo  password gitLink otp otpRecivedTime
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 527 entries, 0 to 526
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   _id                         527 non-null    object
#  1   date                        527 non-null    object
#  2   active                      527 non-null    bool
#  3   archive                     527 non-null    bool
#  4   coursestatus                527 non-null    object
#  5   certificateCollectedStatus  527 non-null    object
#  6   name                        527 non-null    object
#  7   dob                         527 non-null    object
#  8   mobileNumber                527 non-null    int64
#  9   address                     527 non-null    object
#  10  qualification               524 non-null    object
#  11  nationality                 527 non-null    object
#  12  workingDesignation          282 non-null    object
# ...

# %%
data.describe()
# Out:
#        mobileNumber     totalFees  parentNumber    __v   studentId  \
# count  5.270000e+02    527.000000  5.270000e+02  527.0  527.000000
# mean   8.554514e+09  20115.749526  8.768398e+09    0.0  271.206831
# std    1.200020e+09   7700.481354  1.145441e+09    0.0  149.079549
# min    8.910668e+07      0.000000  8.910668e+07    0.0    1.000000
# 25%    7.888081e+09  16000.000000  8.098588e+09    0.0  150.500000
# 50%    8.870354e+09  16000.000000  9.080187e+09    0.0  271.000000
# 75%    9.507395e+09  25000.000000  9.629918e+09    0.0  395.500000
# max    9.994818e+09  46000.000000  9.994924e+09    0.0  527.000000
#
#                otp
# count     2.000000
# mean   2313.000000
# std     151.320851
# min    2206.000000
# 25%    2259.500000
# 50%    2313.000000
# 75%    2366.500000
# max    2420.000000

# %%
data.groupby("pattern").describe()
# Out:
#           mobileNumber                                            \
#                  count          mean           std           min
# pattern
# Full-time        276.0  8.570813e+09  1.256606e+09  8.910668e+07
# Regular          246.0  8.522076e+09  1.141571e+09  6.362661e+09
# Week-end           1.0  8.428821e+09           NaN  8.428821e+09
# Weekend            4.0  9.456252e+09  3.385953e+08  9.080243e+09
#
#                                                                   totalFees  \
#                     25%           50%           75%           max     count
# pattern
# Full-time  7.975554e+09  8.870653e+09  9.585865e+09  9.994818e+09     276.0
# Regular    7.737870e+09  8.838386e+09  9.489269e+09  9.994798e+09     246.0
# Week-end   8.428821e+09  8.428821e+09  8.428821e+09  8.428821e+09       1.0
# Weekend    9.290502e+09  9.424991e+09  9.590741e+09  9.894781e+09       4.0
#
#                          ... studentId          otp                      \
# ...

# %% [markdown]
# ###  Missing data

# %%
df=pd.DataFrame({'A':[1,2,np.nan],
                 'B':[5,np.nan,np.nan],
                 'C':[1,2,3]})

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.fillna(value="**") #you have to fill value as avg / mean , min
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0   **  2
# 2   **   **  3

# %%
#fill na - staistical functions
#dropna - data loss

# %%
data={
    'company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
    'person':['sam','charlie','amy','vanessa','carl','sarah'],
    'sales':[200,120,340,124,243,350]
}

# %%
data
# Out:
# {'company': ['GOOG', 'GOOG', 'MSFT', 'MSFT', 'FB', 'FB'],
#  'person': ['sam', 'charlie', 'amy', 'vanessa', 'carl', 'sarah'],
#  'sales': [200, 120, 340, 124, 243, 350]}

# %%
data=pd.DataFrame(data)

# %%
a=data.groupby("company")

# %%
a.mean(numeric_only=True)
# Out:
#          sales
# company
# FB       296.5
# GOOG     160.0
# MSFT     232.0

# %%
a.std(numeric_only=True)
# Out:
#               sales
# company
# FB        75.660426
# GOOG      56.568542
# MSFT     152.735065

# %%
a.min(numeric_only=True)
# Out:
#          sales
# company
# FB         243
# GOOG       120
# MSFT       124

# %%
a.max(numeric_only=True)
# Out:
#          sales
# company
# FB         350
# GOOG       200
# MSFT       340

# %%
data.isnull().sum()
# Out:
# company    0
# person     0
# sales      0
# dtype: int64
