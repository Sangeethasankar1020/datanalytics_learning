# %% [markdown]
# # EDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("super_market.csv")

# %%
data
# Out:
#     Invoice ID Branch         City Customer type  Gender Product line  \
# 0            1      A     New York        Member    Male       Fruits
# 1            2      B  Los Angeles    Non-member  Female        Dairy
# 2            3      C      Chicago        Member  Female       Bakery
# 3            4      A     New York    Non-member    Male       Grains
# 4            5      B  Los Angeles        Member  Female         Meat
# ..         ...    ...          ...           ...     ...          ...
# 69          70      A     New York    Non-member    Male       Grains
# 70          71      A     New York        Member  Female         Meat
# 71          72      B  Los Angeles    Non-member    Male       Fruits
# 72          73      C      Chicago        Member  Female        Dairy
# 73          74      A     New York    Non-member    Male       Bakery
#
#     Unit price  Quantity  Tax 5%  Total        Date   Time      Payment  \
# ...

# %% [markdown]
# ### Data Understanding

# %%
data.head()
# Out:
#    Invoice ID Branch         City Customer type  Gender Product line  \
# 0           1      A     New York        Member    Male       Fruits
# 1           2      B  Los Angeles    Non-member  Female        Dairy
# 2           3      C      Chicago        Member  Female       Bakery
# 3           4      A     New York    Non-member    Male       Grains
# 4           5      B  Los Angeles        Member  Female         Meat
#
#    Unit price  Quantity  Tax 5%  Total        Date   Time      Payment  cogs  \
# 0         2.0        10    1.00  21.00  2023-01-01  10:00  Credit Card  20.0
# 1         1.5         5    0.38   8.88  2023-01-01  11:00   Debit Card   7.5
# 2         3.0         2    0.30   6.60  2023-01-02  12:00         Cash   6.0
# 3         1.0         8    0.40   8.40  2023-01-02  14:00  Credit Card   8.0
# 4         5.0         3    0.75  15.75  2023-01-03  15:00         Cash  15.0
#
#    gross margin percentage  gross income  Rating
# ...

# %%
data.tail(10)
# Out:
#     Invoice ID Branch         City Customer type  Gender Product line  \
# 64          65      B  Los Angeles        Member  Female       Grains
# 65          66      C      Chicago    Non-member    Male         Meat
# 66          67      A     New York        Member  Female       Fruits
# 67          68      B  Los Angeles    Non-member    Male        Dairy
# 68          69      C      Chicago        Member  Female       Bakery
# 69          70      A     New York    Non-member    Male       Grains
# 70          71      A     New York        Member  Female         Meat
# 71          72      B  Los Angeles    Non-member    Male       Fruits
# 72          73      C      Chicago        Member  Female        Dairy
# 73          74      A     New York    Non-member    Male       Bakery
#
#     Unit price  Quantity  Tax 5%  Total        Date   Time      Payment  \
# 64        1.50         8    0.60  12.60  2023-02-02  15:00         Cash
# ...

# %%
data.describe()
# Out:
#        Invoice ID  Unit price   Quantity     Tax 5%      Total       cogs  \
# count   74.000000   74.000000  74.000000  74.000000  74.000000  73.000000
# mean    37.500000    2.802703   5.418919   0.637432  13.738108  12.726712
# std     21.505813    1.564545   2.415740   0.247232   5.310375   4.986392
# min      1.000000    1.000000   2.000000   0.270000   5.670000   5.400000
# 25%     19.250000    1.750000   3.250000   0.410000   9.082500   8.000000
# 50%     37.500000    2.300000   5.000000   0.630000  13.815000  12.600000
# 75%     55.750000    3.400000   7.750000   0.770000  17.000000  15.400000
# max     74.000000    6.500000  10.000000   1.200000  25.200000  24.000000
#
#        gross margin percentage  gross income     Rating
# count                73.000000     73.000000  73.000000
# mean                  5.753425      0.983151  82.945205
# std                   1.801086      0.498182   7.691789
# min                   5.000000      0.270000  60.000000
# ...

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Invoice ID                   int64
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               74 non-null     int64
#  1   Branch                   74 non-null     object
#  2   City                     74 non-null     object
#  3   Customer type            74 non-null     object
#  4   Gender                   74 non-null     object
#  5   Product line             74 non-null     object
#  6   Unit price               74 non-null     float64
#  7   Quantity                 74 non-null     int64
#  8   Tax 5%                   74 non-null     float64
#  9   Total                    74 non-null     float64
#  10  Date                     74 non-null     object
#  11  Time                     73 non-null     object
#  12  Payment                  73 non-null     object
#  13  cogs                     73 non-null     float64
# ...

# %%
data.nunique()
# Out:
# Invoice ID                 74
# Branch                      3
# City                        3
# Customer type               2
# Gender                      2
# Product line                6
# Unit price                 21
# Quantity                    9
# Tax 5%                     27
# Total                      32
# Date                       38
# Time                       10
# Payment                     3
# cogs                       29
# gross margin percentage     2
# gross income               26
# Rating                     11
# dtype: int64

# %%
data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 69    False
# 70    False
# 71    False
# 72    False
# 73    False
# Length: 74, dtype: bool

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull()
# Out:
#     Invoice ID  Branch   City  Customer type  Gender  Product line  \
# 0        False   False  False          False   False         False
# 1        False   False  False          False   False         False
# 2        False   False  False          False   False         False
# 3        False   False  False          False   False         False
# 4        False   False  False          False   False         False
# ..         ...     ...    ...            ...     ...           ...
# 69       False   False  False          False   False         False
# 70       False   False  False          False   False         False
# 71       False   False  False          False   False         False
# 72       False   False  False          False   False         False
# 73       False   False  False          False   False         False
#
#     Unit price  Quantity  Tax 5%  Total   Date   Time  Payment   cogs  \
# 0        False     False   False  False  False  False    False  False
# ...

# %%
data.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       1
# Payment                    1
# cogs                       1
# gross margin percentage    1
# gross income               1
# Rating                     1
# dtype: int64

# %% [markdown]
# ### Data Cleaning

# %%
data['Payment']
# Out:
# 0     Credit Card
# 1      Debit Card
# 2            Cash
# 3     Credit Card
# 4            Cash
#          ...
# 69     Debit Card
# 70           Cash
# 71    Credit Card
# 72     Debit Card
# 73            NaN
# Name: Payment, Length: 74, dtype: object

# %%
data['Payment'].fillna('Cash',inplace=True)

# %%
data
# Out:
#     Invoice ID Branch         City Customer type  Gender Product line  \
# 0            1      A     New York        Member    Male       Fruits
# 1            2      B  Los Angeles    Non-member  Female        Dairy
# 2            3      C      Chicago        Member  Female       Bakery
# 3            4      A     New York    Non-member    Male       Grains
# 4            5      B  Los Angeles        Member  Female         Meat
# ..         ...    ...          ...           ...     ...          ...
# 69          70      A     New York    Non-member    Male       Grains
# 70          71      A     New York        Member  Female         Meat
# 71          72      B  Los Angeles    Non-member    Male       Fruits
# 72          73      C      Chicago        Member  Female        Dairy
# 73          74      A     New York    Non-member    Male       Bakery
#
#     Unit price  Quantity  Tax 5%  Total        Date   Time      Payment  \
# ...

# %%
data.drop('cogs',axis=1,inplace=True)

# %%
data
# Out:
#     Invoice ID Branch         City Customer type  Gender Product line  \
# 0            1      A     New York        Member    Male       Fruits
# 1            2      B  Los Angeles    Non-member  Female        Dairy
# 2            3      C      Chicago        Member  Female       Bakery
# 3            4      A     New York    Non-member    Male       Grains
# 4            5      B  Los Angeles        Member  Female         Meat
# ..         ...    ...          ...           ...     ...          ...
# 69          70      A     New York    Non-member    Male       Grains
# 70          71      A     New York        Member  Female         Meat
# 71          72      B  Los Angeles    Non-member    Male       Fruits
# 72          73      C      Chicago        Member  Female        Dairy
# 73          74      A     New York    Non-member    Male       Bakery
#
#     Unit price  Quantity  Tax 5%  Total        Date   Time      Payment  \
# ...

# %%
data['gross margin percentage'].mean()
# Out:
# 5.7534246575342465

# %%
data['gross margin percentage'].fillna(data['gross margin percentage'].mean(),inplace=True)

# %%
data
# Out:
#     Invoice ID Branch         City Customer type  Gender Product line  \
# 0            1      A     New York        Member    Male       Fruits
# 1            2      B  Los Angeles    Non-member  Female        Dairy
# 2            3      C      Chicago        Member  Female       Bakery
# 3            4      A     New York    Non-member    Male       Grains
# 4            5      B  Los Angeles        Member  Female         Meat
# ..         ...    ...          ...           ...     ...          ...
# 69          70      A     New York    Non-member    Male       Grains
# 70          71      A     New York        Member  Female         Meat
# 71          72      B  Los Angeles    Non-member    Male       Fruits
# 72          73      C      Chicago        Member  Female        Dairy
# 73          74      A     New York    Non-member    Male       Bakery
#
#     Unit price  Quantity  Tax 5%  Total        Date   Time      Payment  \
# ...

# %%
data
# Out:
#     Invoice ID Branch         City Customer type  Gender Product line  \
# 0            1      A     New York        Member    Male       Fruits
# 1            2      B  Los Angeles    Non-member  Female        Dairy
# 2            3      C      Chicago        Member  Female       Bakery
# 3            4      A     New York    Non-member    Male       Grains
# 4            5      B  Los Angeles        Member  Female         Meat
# ..         ...    ...          ...           ...     ...          ...
# 69          70      A     New York    Non-member    Male       Grains
# 70          71      A     New York        Member  Female         Meat
# 71          72      B  Los Angeles    Non-member    Male       Fruits
# 72          73      C      Chicago        Member  Female        Dairy
# 73          74      A     New York    Non-member    Male       Bakery
#
#     Unit price  Quantity  Tax 5%  Total        Date   Time      Payment  \
# ...

# %%
data['Time'] = pd.to_datetime(data['Time'])
# Out:
# C:\Users\DELL 4\AppData\Local\Temp\ipykernel_13648\3567905165.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Time'] = pd.to_datetime(data['Time'])

# %%
data
# Out:
#     Invoice ID Branch         City Customer type  Gender Product line  \
# 0            1      A     New York        Member    Male       Fruits
# 1            2      B  Los Angeles    Non-member  Female        Dairy
# 2            3      C      Chicago        Member  Female       Bakery
# 3            4      A     New York    Non-member    Male       Grains
# 4            5      B  Los Angeles        Member  Female         Meat
# ..         ...    ...          ...           ...     ...          ...
# 69          70      A     New York    Non-member    Male       Grains
# 70          71      A     New York        Member  Female         Meat
# 71          72      B  Los Angeles    Non-member    Male       Fruits
# 72          73      C      Chicago        Member  Female        Dairy
# 73          74      A     New York    Non-member    Male       Bakery
#
#     Unit price  Quantity  Tax 5%  Total        Date                Time  \
# ...

# %%
data['Time'].fillna(data['Time'].mean(),inplace=True)
# Out:
# C:\Users\DELL 4\AppData\Local\Temp\ipykernel_13648\2206979494.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Time'].fillna(data['Time'].mean(),inplace=True)

# %%
data
# Out:
#     Invoice ID Branch         City Customer type  Gender Product line  \
# 0            1      A     New York        Member    Male       Fruits
# 1            2      B  Los Angeles    Non-member  Female        Dairy
# 2            3      C      Chicago        Member  Female       Bakery
# 3            4      A     New York    Non-member    Male       Grains
# 4            5      B  Los Angeles        Member  Female         Meat
# ..         ...    ...          ...           ...     ...          ...
# 69          70      A     New York    Non-member    Male       Grains
# 70          71      A     New York        Member  Female         Meat
# 71          72      B  Los Angeles    Non-member    Male       Fruits
# 72          73      C      Chicago        Member  Female        Dairy
# 73          74      A     New York    Non-member    Male       Bakery
#
#     Unit price  Quantity  Tax 5%  Total        Date  \
# 0         2.00        10    1.00  21.00  2023-01-01
# ...

# %%
data['gross income'].fillna(data['gross income'].mean(),inplace=True)
# Out:
# C:\Users\DELL 4\AppData\Local\Temp\ipykernel_13648\167631749.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['gross income'].fillna(data['gross income'].mean(),inplace=True)

# %%
data
# Out:
#     Invoice ID Branch         City Customer type  Gender Product line  \
# 0            1      A     New York        Member    Male       Fruits
# 1            2      B  Los Angeles    Non-member  Female        Dairy
# 2            3      C      Chicago        Member  Female       Bakery
# 3            4      A     New York    Non-member    Male       Grains
# 4            5      B  Los Angeles        Member  Female         Meat
# ..         ...    ...          ...           ...     ...          ...
# 69          70      A     New York    Non-member    Male       Grains
# 70          71      A     New York        Member  Female         Meat
# 71          72      B  Los Angeles    Non-member    Male       Fruits
# 72          73      C      Chicago        Member  Female        Dairy
# 73          74      A     New York    Non-member    Male       Bakery
#
#     Unit price  Quantity  Tax 5%  Total        Date  \
# 0         2.00        10    1.00  21.00  2023-01-01
# ...

# %%
data['Rating'].fillna( data['Rating'].mean(),inplace=True)

# %%
data
# Out:
#     Invoice ID Branch         City Customer type  Gender Product line  \
# 0            1      A     New York        Member    Male       Fruits
# 1            2      B  Los Angeles    Non-member  Female        Dairy
# 2            3      C      Chicago        Member  Female       Bakery
# 3            4      A     New York    Non-member    Male       Grains
# 4            5      B  Los Angeles        Member  Female         Meat
# ..         ...    ...          ...           ...     ...          ...
# 69          70      A     New York    Non-member    Male       Grains
# 70          71      A     New York        Member  Female         Meat
# 71          72      B  Los Angeles    Non-member    Male       Fruits
# 72          73      C      Chicago        Member  Female        Dairy
# 73          74      A     New York    Non-member    Male       Bakery
#
#     Unit price  Quantity  Tax 5%  Total        Date  \
# 0         2.00        10    1.00  21.00  2023-01-01
# ...
