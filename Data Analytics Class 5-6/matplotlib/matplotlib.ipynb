# %% [markdown]
# # Matplotlib

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=np.linspace(0,5,11)
y=x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("Example")
plt.show()

# %%
x=np.array(["A","B","C","D","E","F","G","H"])
y=np.array([10,5,8,20,25,80,90,10])

# %%
plt.bar(x,y)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("Bar")
plt.show()

# %%
x=np.random.normal(20,10,20)

# %%
plt.hist(x)
plt.title("Histogram")
plt.show()

# %%
y=np.array([10,5,8,20,25,80,90,10])

# %%
plt.pie(y)
plt.title("Pie Chart")
plt.show()

# %%
x=np.array([10,102,30,190,30])
y=np.array([30,60,70,89,30])

# %%
plt.scatter(x,y)
plt.title("Scatter Plot")
plt.show()

# %% [markdown]
# ### Subplots

# %%
x=np.linspace(0,5,11)
y=x**2

# %%
plt.subplot(1,2,1)
plt.plot(x,y,"g--")
plt.title("subplot 1")
plt.subplot(1,2,2)
plt.plot(y,x,"r*-")
plt.title("subplot 2")
plt.show()

# %%
#object oriented

# %%
fig=plt.figure()

axes=fig.add_axes([.1,.1,.8,.8])
axes.plot(x,y,"r")
axes.set_xlabel("x axis")
axes.set_ylabel("y axis")
axes.set_title("sample")
# Out:
# Text(0.5, 1.0, 'sample')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # inset axes

# Larger Figure Axes 1
axes1.plot(x, y, 'b')
axes1.set_xlabel('X_label_axes2')
axes1.set_ylabel('Y_label_axes2')
axes1.set_title('Axes 2 Title')

# Insert Figure Axes 2
axes2.plot(y, x, 'r')
axes2.set_xlabel('X_label_axes2')
axes2.set_ylabel('Y_label_axes2')
axes2.set_title('Axes 2 Title');

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

# %%
for i in axes:
    i.plot(x, y, 'b')
    i.set_xlabel('x')
    i.set_ylabel('y')
    i.set_title('title')

# %%
fig

# %%
# fig = plt.figure(figsize=(8,4), dpi=100) #quality

# %%
fig,axes=plt.subplots(figsize=(12,3))
axes.plot(x,y,'b')
axes.set_xlabel('X')
axes.set_ylabel('Y')
axes.set_title('ocean')
# Out:
# Text(0.5, 1.0, 'ocean')

# %%
fig.savefig("file1.png")

# %%
fig.savefig("file3.png",dpi=400)

# %%
#legends

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, x**2, label="x**2")
ax.plot(x, x**3, label="x**3")
ax.legend()
