# %% [markdown]
# # Univariate

# %% [markdown]
# #  Distribution plot

# %% [markdown]
# - displot
# - rugplot
# - kdeplot

# %% [markdown]
# ### Import

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Data

# %% [markdown]
# Seaborn comes with built-in data sets!

# %%
df=sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### displot - Distribution plot

# %% [markdown]
# The distplot shows the distribution of a univariate set of observations.

# %%
sns.displot(df['total_bill'],kde=True)

# %%
#bins - interval difference

# %% [markdown]
# ### rug plot

# %% [markdown]
# rugplots are actually a very simple concept, they just draw a dash mark for every point on a univariate distribution. They are the building block of a KDE plot:

# %%
sns.rugplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %% [markdown]
# ### kdeplot

# %% [markdown]
# kdeplots are Kernel Density Estimation plots. These KDE plots replace every single observation with a Gaussian (Normal) distribution centered around that value. For example:

# %%
sns.kdeplot(df['total_bill'])
sns.rugplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(df['tip'])
sns.rugplot(df['tip'])
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %% [markdown]
# # Categorical Data Plots

# %% [markdown]
# Now let's discuss using seaborn to plot categorical data! There are a few main plot types for this:

# %% [markdown]
# - factorplot
# - boxplot
# - violinplot
# - stripplot
# - swarmplot
# - barplot
# - countplot

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### barplot

# %% [markdown]
# These very similar plots allow you to get aggregate data off a categorical feature in your data. barplot is a general plot that allows you to aggregate the categorical data based off some function, by default the mean:

# %%
sns.barplot(x='sex',y='total_bill',data=df) #default it gives estimated as mean
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# You can change the estimator object to your own function, that converts a vector to a scalar:

# %%
sns.barplot(x='sex',y='total_bill',data=df,estimator=np.std)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ### count plot

# %% [markdown]
# This is essentially the same as barplot except the estimator is explicitly counting the number of occurrences. Which is why we only pass the x value:

# %%
sns.countplot(x='sex',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# ### boxplot and violinplot

# %% [markdown]
# boxplots and violinplots are used to shown the distribution of categorical data. A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable. The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be “outliers” using a method that is a function of the inter-quartile range.

# %%
sns.boxplot(x='sex',y='total_bill',data=df,palette='rainbow')
# Out:
# C:\Users\DELL 4\AppData\Local\Temp\ipykernel_4980\2258605995.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='sex',y='total_bill',data=df,palette='rainbow')
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.boxplot(data=df,palette='rainbow')
# Out:
# <Axes: >

# %%
#for vertical

# %%
sns.boxplot(data=df,palette='rainbow',orient='h')
# Out:
# <Axes: >

# %%
sns.boxplot(x='sex', y='total_bill', hue='smoker', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ### catplot

# %% [markdown]
# For the univariate analysis, we'll examine a single categorical variable. Let's use a count plot to show the distribution of the day variable (the day of the week):

# %%
# Univariate analysis: Count plot of 'day'
sns.catplot(x='day', kind='count', data=df)
plt.title('Count Plot of Days')
plt.show()

# %% [markdown]
# For the bivariate analysis, we can examine the relationship between a categorical variable (day) and a continuous variable (total_bill). We will use a box plot to see how the total bill varies across different days:

# %%
# Bivariate analysis: Box plot of 'total_bill' by 'day'
sns.catplot(x='day', y='total_bill', kind='box', data=df)
plt.title('Box Plot of Total Bill by Day')
plt.show()

# %% [markdown]
# In the multivariate analysis, we can add another dimension to our plot using the hue parameter. Let's examine the relationship between day, total_bill, and sex of the customers:

# %%
# Multivariate analysis: Box plot of 'total_bill' by 'day', with 'sex' as hue
sns.catplot(x='day', y='total_bill', hue='sex', kind='box', data=df)
plt.title('Box Plot of Total Bill by Day and Gender')
plt.show()
