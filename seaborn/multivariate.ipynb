# %% [markdown]
# # Multivariate

# %% [markdown]
# # distribution

# %% [markdown]
# ### pairplot

# %% [markdown]
# pairplot will plot pairwise relationships across an entire dataframe (for the numerical columns) and supports a color hue argument (for categorical columns).

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(df)
#efficient for small data
#time does not comes under categorical also day not comes under actegorical

# %%
sns.pairplot(df, hue='sex', palette='coolwarm') #palette design

# %% [markdown]
# # Matrix Plots

# %% [markdown]
# Matrix plots allow you to plot data as color-encoded matrices

# %% [markdown]
# Let's begin by exploring seaborn's heatmap

# %%
fl=sns.load_dataset('flights')

# %%
fl
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %% [markdown]
# ### heat map - mostly we use

# %%
#usually number - heatmap easy

# %%
fl.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# In order for a heatmap to work properly, your data should already be in a matrix form, the sns.heatmap function basically just colors it in for you. For example:

# %%
#selecting numberic only for correlation

# %%
numeric_df=df.select_dtypes(include='number')

# %%
numeric_df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
#its as positive co-relation - above .5 is good corellation , we have to ask domain experise also

# %%
#heatmap - for correlation

# %%
sns.heatmap(numeric_df.corr())
# Out:
# <Axes: >

# %%
#value view
sns.heatmap(numeric_df.corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
#for fl data

# %%
fp=fl.pivot_table(values='passengers',index='month',columns='year')
# Out:
# C:\Users\DELL 4\AppData\Local\Temp\ipykernel_3248\1445051112.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   fp=fl.pivot_table(values='passengers',index='month',columns='year')

# %%
fp
# Out:
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# Aug    148.0  170.0  199.0  242.0  272.0  293.0  347.0  405.0  467.0  505.0
# Sep    136.0  158.0  184.0  209.0  237.0  259.0  312.0  355.0  404.0  404.0
# Oct    119.0  133.0  162.0  191.0  211.0  229.0  274.0  306.0  347.0  359.0
# Nov    104.0  114.0  146.0  172.0  180.0  203.0  237.0  271.0  305.0  310.0
# ...

# %%
fp=fl.pivot_table(values='passengers',index='month',columns='year')
sns.heatmap(fp)
# Out:
# C:\Users\DELL 4\AppData\Local\Temp\ipykernel_3248\3090356299.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   fp=fl.pivot_table(values='passengers',index='month',columns='year')
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.heatmap(fp,cmap='magma',linecolor='white',linewidth=1)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# # Grid

# %% [markdown]
# ### join grid

# %% [markdown]
# JointGrid is the general version for jointplot() type grids, for a quick example:

# %%
tips = sns.load_dataset('tips')
g = sns.JointGrid(x="total_bill", y="tip", data=tips)

# %%
g = sns.JointGrid(x="total_bill", y="tip", data=tips)
g = g.plot(sns.regplot, sns.displot)
# Out:
# C:\Users\DELL 4\anaconda3\Lib\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL 4\anaconda3\Lib\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
